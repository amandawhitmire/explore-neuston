# %% [markdown]
# # A notebook to test a custom entity set for doing NER on the Stanford Oceanographic Expeditions, looking for words associated with neuston.
#
# In partnership with Rebecca Helm, Assistant Professor, University of North Carolina, Asheville and Research Associate, Smithsonian Institution, NMNH
#
# The setup blocks for this notebook are adapted from portions of The Datasitter's Club, specifically, this Notebook:
#
# Skallerup Bessette, Lee and Quinn Quinn. “DSC Multilingual Mystery 2: Beware, Lee and Quinn!”. February 27, 2020. https://datasittersclub.github.io/site/dscm2.html.
#
# I am so grateful for the work that Quinn so generously documents and shares openly.

# %% [markdown]
# ## 1. Downloading spaCy models
#
# The first step is to download the spaCy model. The model has been pre-trained on annotated English corpora. You only have to run these code cells below the first time you run the notebook; after that, you can skip right to step 2 and carry on from there. (If you run them again later, nothing bad will happen; it’ll just download again.) You can also run spaCy in other notebooks on your computer in the future, and you’ll be able to skip the step of downloading the models.

# %%
#Installs the English spaCy model
# !python -m spacy download en_core_web_sm
# Out:
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.1.0/en_core_web_trf-3.1.0.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.1.0/en_core_web_trf-3.1.0.tar.gz (460.2 MB)
#      |████████████████████████████████| 460.2 MB 13 kB/s  eta 0:00:017   |██▍                             | 34.7 MB 6.9 MB/s eta 0:01:02     |█████████▍                      | 135.1 MB 7.6 MB/s eta 0:00:44     |█████████████                   | 186.9 MB 6.6 MB/s eta 0:00:42     |█████████████▌                  | 193.6 MB 5.1 MB/s eta 0:00:53
# Requirement already satisfied: spacy<3.2.0,>=3.1.0 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from en-core-web-trf==3.1.0) (3.1.1)
# Requirement already satisfied: spacy-transformers<1.1.0,>=1.0.3 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from en-core-web-trf==3.1.0) (1.0.4)
# Requirement already satisfied: setuptools in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-trf==3.1.0) (57.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-trf==3.1.0) (1.8.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-trf==3.1.0) (2.0.5)
# Requirement already satisfied: numpy>=1.15.0 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-trf==3.1.0) (1.21.2)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-trf==3.1.0) (0.3.2)
# Requirement already satisfied: pathy>=0.3.5 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-trf==3.1.0) (0.6.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-trf==3.1.0) (3.0.5)
# Requirement already satisfied: jinja2 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-trf==3.1.0) (3.0.1)
# Requirement already satisfied: thinc<8.1.0,>=8.0.8 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-trf==3.1.0) (8.0.8)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-trf==3.1.0) (2.26.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-trf==3.1.0) (0.7.4)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-trf==3.1.0) (2.4.1)
# Requirement already satisfied: packaging>=20.0 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-trf==3.1.0) (21.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-trf==3.1.0) (2.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-trf==3.1.0) (0.8.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-trf==3.1.0) (4.62.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.7 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-trf==3.1.0) (3.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-trf==3.1.0) (1.0.5)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.2.0,>=3.1.0->en-core-web-trf==3.1.0) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from pathy>=0.3.5->spacy<3.2.0,>=3.1.0->en-core-web-trf==3.1.0) (5.1.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.2.0,>=3.1.0->en-core-web-trf==3.1.0) (3.10.0.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-trf==3.1.0) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-trf==3.1.0) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-trf==3.1.0) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-trf==3.1.0) (3.2)
# Requirement already satisfied: torch>=1.5.0 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from spacy-transformers<1.1.0,>=1.0.3->en-core-web-trf==3.1.0) (1.9.0)
# Requirement already satisfied: spacy-alignments<1.0.0,>=0.7.2 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from spacy-transformers<1.1.0,>=1.0.3->en-core-web-trf==3.1.0) (0.8.3)
# Requirement already satisfied: transformers<4.10.0,>=3.4.0 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from spacy-transformers<1.1.0,>=1.0.3->en-core-web-trf==3.1.0) (4.9.2)
# Requirement already satisfied: sacremoses in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from transformers<4.10.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.3->en-core-web-trf==3.1.0) (0.0.45)
# Requirement already satisfied: regex!=2019.12.17 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from transformers<4.10.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.3->en-core-web-trf==3.1.0) (2021.8.3)
# Requirement already satisfied: huggingface-hub==0.0.12 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from transformers<4.10.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.3->en-core-web-trf==3.1.0) (0.0.12)
# Requirement already satisfied: pyyaml>=5.1 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from transformers<4.10.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.3->en-core-web-trf==3.1.0) (5.4.1)
# Requirement already satisfied: filelock in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from transformers<4.10.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.3->en-core-web-trf==3.1.0) (3.0.12)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from transformers<4.10.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.3->en-core-web-trf==3.1.0) (0.10.3)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from typer<0.4.0,>=0.3.0->spacy<3.2.0,>=3.1.0->en-core-web-trf==3.1.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from jinja2->spacy<3.2.0,>=3.1.0->en-core-web-trf==3.1.0) (2.0.1)
# Requirement already satisfied: six in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from sacremoses->transformers<4.10.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.3->en-core-web-trf==3.1.0) (1.16.0)
# Requirement already satisfied: joblib in /Users/thalassa/opt/anaconda3/envs/leading2/lib/python3.8/site-packages (from sacremoses->transformers<4.10.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.3->en-core-web-trf==3.1.0) (1.0.1)

# %% [markdown]
# ## 2. Importing spaCy and setting up NLP
#
# Run the code cell below to import the spaCy module, and create a functions to loads the Englsih model and run the NLP algorithms (includes named-entity recognition).

# %%
#Imports spaCy
import spacy

#Imports the English model
import en_core_web_sm

#Sets up a function so you can run the English model on texts
nlp = en_core_web_sm.load()

# %% [markdown]
# ## 3. Importing other modules
#
# There’s various other modules that will be useful in this notebook. The code comments explain what each one is for. This code cell imports all of those.

# %%
#io is used for opening and writing files
import io

#glob is used to find all the pathnames matching a specified pattern (here, all text files)
import glob

#os is used to navigate your folder directories (e.g. change folders to where you files are stored)
import os

# for handling data frames, etc.
import pandas as pd

# Import the spaCy visualizer
from spacy import displacy

# Import the Entityt Ruler for making custom entities
from spacy.pipeline import EntityRuler

# %% [markdown]
# ## 4. Diretory setup
#
# Assuming you’re running Jupyter Notebook from your computer’s home directory, this code cell gives you the opportunity to change directories, into the directory where you’re keeping your project files. I've put just a few of the ANSP volumes into a folder called `subset`.

# %%
#Define the file directory here
filedirectory = '../data'

#Change the working directory to the one you just defined
os.chdir(filedirectory)

# %% [markdown]
# # Tagging custom entities with spaCy
#
# I'm going to be using the Global Names Recognition and Discovery tools to automate identifying genus and species names in the ANSP volumes. From there, I'll need to load to species names into spaCy so they can be tagged via the NER pipeline. Let's do a small test on our example from above.
#
# We already loaded spaCy's model `en_core_web_trf` as "nlp" in a prior code chunk. Now we need to create a new pipeline step using Entity Ruler (https://spacy.io/api/entityruler). We use the scientific names as our new entity pattern, and use SPECIES as the entity label.
#
# These are the species names mentioned above, plus one I added just as a test.
# species = ['Ariolimax niger', 'A. Californicus', 'Homo sapiens']
#
# I created a JSONL file (really a text file with the file extension changed, lol) with the required format:
#
# >{"label": "SPECIES", "pattern": "Ariolimax niger"}
# >{"label": "SPECIES", "pattern": "A. Californicus"}
# >{"label": "SPECIES", "pattern": "Homo sapiens"}
#
# and saved it as species-examples.jsonl
#
# Now, we will add these entities to the NLP pipeline by using the Entity Ruler (the Ruler of All Entities?).
#
# This is the spaCy NLP pipeline (from spacy.io)
#
# <img src="https://spacy.io/pipeline-fde48da9b43661abcdf62ab70a546d71.svg" alt="NLP-Pipeline" width="600"/>

# %% [markdown]
# ## Define an entity ruler
#
# We need to tell the pipeline where we want to add in the new pipeline component. We want it to add the new entity ruler *before* we do the NER step.

# %%
ruler = nlp.add_pipe("entity_ruler", before='ner') # <- this is directly from spacy documentation

# %%
# Load the new pattern (your list of custom entities) by adding them from the properly formatted jsonl file.
ruler.from_disk("/Users/thalassa/Notebooks/helm.jsonl")

# %%
# ruler = nlp.remove_pipe("ner")

# %%
# Check the pipeline. The entity_ruler should be listed *before* ner.
nlp.pipeline
# Out:
# [('transformer',
#   <spacy_transformers.pipeline_component.Transformer at 0x7fd1626a8ef0>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x7fd162704d60>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x7fd1626fbb80>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x7fd1627470c0>),
#  ('lemmatizer',
#   <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x7fd162747f40>),
#  ('entity_ruler', <spacy.pipeline.entityruler.EntityRuler at 0x7fd160aaf440>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x7fd1627641c0>)]

# %% [markdown]
# # Test if the new entities (HELM) are identified in the new pipeline

# %%
with open("/Users/thalassa/Google Drive/Shared drives/Miller Library/Collections/StanfordOceanographicExpeditions/OLD_TE VEGA NARRATIVES/txt/Cruise 01 Installment 01 Narrative_MT.txt") as f:
    text = f.read()

# %%
# Look at the first bit of text
print(text[1:500])
# Out:
# E VEGA EXPEDITIONS MAIDEN VOYAGE--GENERAL NARRATIVE
#
# July 14. 1963. In the prospectus for Cruise 1, TE VEGA was scheduled to sail "on or about June 17." Toward the first of June, it became clear that there would be a short delay and the students were notified that they should await further orders before joining the ship. As time went on, all hope of having the ship leave from Monterey was abandoned, and the students were finally instructed to join the ship in fan Diego on June 30th, in time fo

# %%
# Just run the default NER, disabling the other NLP junk
doc = nlp(text)

# %%
# look at the results
# print([(ent.text, ent.label_) for ent in doc.ents])

# %%
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TE VEGA EXPEDITIONS MAIDEN VOYAGE--GENERAL NARRATIVE
#
# July 14.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1963
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . In the prospectus for
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cruise 1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TE VEGA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  was scheduled to sail &quot;on or about
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     June 17
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .&quot; Toward
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the first of June
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , it became clear that there would be a short delay and the students were notified that they should await further orders before joining the ship. As time went on, all hope of having the ship leave from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monterey
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  was abandoned, and the students were finally instructed to join the ship in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fan Diego
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     June 30th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , in time for a simple dedication ceremony on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     July 1st
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , whereupon the vessel would sail immediately. </br></br>The dedication ceremony went off on schedule with a goodly crowd of well-wishers present. The ship went to
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the B Street Pier
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  where brief remarks were offered by Dean
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Frederick Terman
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Provost of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Stanford University
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , Dr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Harve Carlson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the National Science Foundation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , Dr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     John Ryther
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  representing
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the International Indian Ocean Expeditions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , Dr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     L. R. Blinks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Director of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Hopkins Marine Station
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , Dr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     R. L. Bolin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Chief Scientist of the Expedition, and Capt.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     E. B. Olsen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Master of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TE VEGA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . After the ship was signified to be recommissioned by the raising of a burgee showing a red dolphin on a white field, visitors inspected her under the guidance of the students, and later there was a reception at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; li

# %%
# put the results into a dataframe - why not?!
data = pd.DataFrame([ (ent.text, ent.label_ ) for ent in doc.ents], columns=["Text", "Label"] )

# %%
# Let's check it out
data.head()
# Out:
#           Text     Label
# 0           13  CARDINAL
# 1  August 15th      DATE
# 2      Mayotte       GPE
# 3       Comoro       LOC
# 4         fish      HELM

# %% [markdown]
# # Exporting NER results
#
# Now that we've figurd out the process, it's time to go through each file, do the NLP, and save the results of the NER.

# %%
#Sort all the files in the directory you specified above, alphabetically.

#For each of those files...
for filename in sorted(os.listdir(filedirectory)):
    #If the filename ends with .txt (i.e. if it's actually a text files)
    if filename.endswith('.txt'):
        #Write out below the name of the file
        print(filename)
        #The file name of the output file adds _ner to the end of the file name of the input file
        outfilename = filename.replace('.txt', '_ner.txt')
        # Open the infput filename
        with open(filename, 'r') as f:
            # Create and open the output filename
            with open(outfilename, 'w') as out:
                # Read the contents of the input file
                text = f.read()
                # Do NLP on the contents of the input file
                ner = nlp(text)
                # Create a dataframe with the NER results
                data = pd.DataFrame([ (ent.text, ent.label_ ) for ent in doc.ents], columns=["Text", "Label"] )
                # Save results as CSV file
                data.to_csv(outfilename, index_label= "Index")
# Out:
# Installment 01 Narrative.txt
# Installment 02 Narrative.txt
# Installment 03 Narrative.txt
# Installment 04 Narrative.txt
# Installment 05 Narrative.txt
# Installment 06 Narrative.txt
# Installment 07 Narrative.txt
# Installment 08 Narrative.txt
# Installment 09 Narrative.txt
# Installment 11 Narrative.txt
# Installment 12 Narrative.txt
# Installment 13 Narrative.txt
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-32-1755be77753a> in <module>
#      14             with open(outfilename, 'w') as out:
#      15                 # Read the contents of the input file
# ---> 16                 text = f.read()
#      17                 # Do NLP on the contents of the input file
#      18                 ner = nlp(text)
#
# ~/opt/anaconda3/envs/leading/lib/python3.8/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa3 in position 17: invalid start byte

# %% [markdown]
# # Exporting annotation visuals

# %%
svg = displacy.render(doc, style="ent", jupyter=False)

# %%
outfilename = filename.replace('.txt', '.svg')
# Out:
# Installment 13 Narrative.svg

# %%
from pathlib import Path

# %%
output_path = Path("/images/" + outfilename)
print(output_path)
# Out:
# /images/Installment 13 Narrative.svg

# %%
outfilename.open("w", encoding="utf-8").write(svg)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-5d2ce9306ded> in <module>
# ----> 1 outfilename.open("w", encoding="utf-8").write(svg)
#
# AttributeError: 'str' object has no attribute 'open'

# %%
html = displacy.render(doc, style="ent", page=True)
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">TE VEGA EXPEDITIONS</br>GENERAL NARRATIVE INSTALLMENT
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     13
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br></br>On
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     August 15th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  we reached
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mayotte
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , the easternmost island of the
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Comoro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  group. This is almost entirely sur.rounded by a barrier reef and, from its appearance on the chart and from verbal reports, promised to provide spec.tacular coral 0ardens and excellent
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">HELM</span>
# </mark>
# -collecting sites.</br></br>As we approached, the wind, which had deserted us during the crossing, sprang up fresh and strong just when we did not welcome it. By
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mid-
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     morning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# , we were off the northern end of the island, where the western limit of a long line of breakers indicated the position of the narrow entrance of
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Passe M'Zambourou
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . Once inside the reef, the chart showed a maze of coral heads and shallow patches,but buoys and ran 0e markers made the channel easy to follow. A little before lunch time we were safely at anchor in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Baie de Langoni
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# , but by then the wind was heavy and kicking up a nasty whitecapped chop within
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a couple of hundred yards
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  of
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the lee shore
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . A little scouting with a glass-bottomed box from
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Boston
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  whalers showed nice development of coral on the fringing reef, but the water was murky and the waves and strong current made conditions unsuitable for work. Attack on the outer barrier reef
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about five miles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  off shore was out of the question because of the heavy breakers. The time remaining for our
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     second
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  attempt to catch a coelacanth was running short, and we could ill afford to wait for conditions to improve. Consequently,with considerable re3ret we gave up the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mayotte
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  venture that we had all looked forward to as an interesting break in our routine program, and
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     early that same afternoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  we left again without having set foot on the island.</br></br>By
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one o'clock in the morning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sunday, August 15th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , we were once more in our old stamping ground off the northern coast of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-
